# %%
##https://realpython.com/beautiful-soup-web-scraper-python/

import requests
from bs4 import BeautifulSoup


URL = "https://realpython.github.io/fake-jobs/"
page = requests.get(URL)


soup = BeautifulSoup(page.content, "html.parser")


results = soup.find(id="ResultsContainer")


job_elements = results.find_all("div", class_="card-content")


for job_element in job_elements:
    title_element = job_element.find("h2", class_="title")
    company_element = job_element.find("h3", class_="company")
    location_element = job_element.find("p", class_="location")
    print("Title of Job =",title_element.text.strip())
    print("Company Name =",company_element.text.strip())
    print("Location of Job =",location_element.text.strip())
    print()
# Out:
# Title of Job = Senior Python Developer
# Company Name = Payne, Roberts and Davis
# Location of Job = Stewartbury, AA
#
# Title of Job = Energy engineer
# Company Name = Vasquez-Davidson
# Location of Job = Christopherville, AA
#
# Title of Job = Legal executive
# Company Name = Jackson, Chambers and Levy
# Location of Job = Port Ericaburgh, AA
#
# Title of Job = Fitness centre manager
# Company Name = Savage-Bradley
# Location of Job = East Seanview, AP
#
# Title of Job = Product manager
# Company Name = Ramirez Inc
# Location of Job = North Jamieview, AP
#
# Title of Job = Medical technical officer
# Company Name = Rogers-Yates
# Location of Job = Davidville, AP
#
# Title of Job = Physiological scientist
# Company Name = Kramer-Klein
# Location of Job = South Christopher, AE
#
# Title of Job = Textile designer
# Company Name = Meyers-Johnson
# Location of Job = Port Jonathan, AE
#
# Title of Job = Television floor manager
# Company Name = Hughes-Williams
# Location of Job = Osbornetown, AE
#
# Title of Job = Waste management officer
# Company Name = Jones, Williams and Villa
# Location of Job = Scotttown, AP
#
# Title of Job = Software Engineer (Python)
# Company Name = Garcia PLC
# Location of Job = Ericberg, AE
#
# Title of Job = Interpreter
# Company Name = Gregory and Sons
# Location of Job = Ramireztown, AE
#
# Title of Job = Architect
# Company Name = Clark, Garcia and Sosa
# Location of Job = Figueroaview, AA
#
# Title of Job = Meteorologist
# Company Name = Bush PLC
# Location of Job = Kelseystad, AA
#
# Title of Job = Audiological scientist
# Company Name = Salazar-Meyers
# Location of Job = Williamsburgh, AE
#
# Title of Job = English as a second language teacher
# Company Name = Parker, Murphy and Brooks
# Location of Job = Mitchellburgh, AE
#
# Title of Job = Surgeon
# Company Name = Cruz-Brown
# Location of Job = West Jessicabury, AA
#
# Title of Job = Equities trader
# Company Name = Macdonald-Ferguson
# Location of Job = Maloneshire, AE
#
# Title of Job = Newspaper journalist
# Company Name = Williams, Peterson and Rojas
# Location of Job = Johnsonton, AA
#
# Title of Job = Materials engineer
# Company Name = Smith and Sons
# Location of Job = South Davidtown, AP
#
# Title of Job = Python Programmer (Entry-Level)
# Company Name = Moss, Duncan and Allen
# Location of Job = Port Sara, AE
#
# Title of Job = Product/process development scientist
# Company Name = Gomez-Carroll
# Location of Job = Marktown, AA
#
# Title of Job = Scientist, research (maths)
# Company Name = Manning, Welch and Herring
# Location of Job = Laurenland, AE
#
# Title of Job = Ecologist
# Company Name = Lee, Gutierrez and Brown
# Location of Job = Lauraton, AP
#
# Title of Job = Materials engineer
# Company Name = Davis, Serrano and Cook
# Location of Job = South Tammyberg, AP
#
# Title of Job = Historic buildings inspector/conservation officer
# Company Name = Smith LLC
# Location of Job = North Brandonville, AP
#
# Title of Job = Data scientist
# Company Name = Thomas Group
# Location of Job = Port Robertfurt, AA
#
# Title of Job = Psychiatrist
# Company Name = Silva-King
# Location of Job = Burnettbury, AE
#
# Title of Job = Structural engineer
# Company Name = Pierce-Long
# Location of Job = Herbertside, AA
#
# Title of Job = Immigration officer
# Company Name = Walker-Simpson
# Location of Job = Christopherport, AP
#
# Title of Job = Python Programmer (Entry-Level)
# Company Name = Cooper and Sons
# Location of Job = West Victor, AE
#
# Title of Job = Neurosurgeon
# Company Name = Donovan, Gonzalez and Figueroa
# Location of Job = Port Aaron, AP
#
# Title of Job = Broadcast engineer
# Company Name = Morgan, Butler and Bennett
# Location of Job = Loribury, AA
#
# Title of Job = Make
# Company Name = Snyder-Lee
# Location of Job = Angelastad, AP
#
# Title of Job = Nurse, adult
# Company Name = Harris PLC
# Location of Job = Larrytown, AE
#
# Title of Job = Air broker
# Company Name = Washington PLC
# Location of Job = West Colin, AP
#
# Title of Job = Editor, film/video
# Company Name = Brown, Price and Campbell
# Location of Job = West Stephanie, AP
#
# Title of Job = Production assistant, radio
# Company Name = Mcgee PLC
# Location of Job = Laurentown, AP
#
# Title of Job = Engineer, communications
# Company Name = Dixon Inc
# Location of Job = Wrightberg, AP
#
# Title of Job = Sales executive
# Company Name = Thompson, Sheppard and Ward
# Location of Job = Alberttown, AE
#
# Title of Job = Software Developer (Python)
# Company Name = Adams-Brewer
# Location of Job = Brockburgh, AE
#
# Title of Job = Futures trader
# Company Name = Schneider-Brady
# Location of Job = North Jason, AE
#
# Title of Job = Tour manager
# Company Name = Gonzales-Frank
# Location of Job = Arnoldhaven, AE
#
# Title of Job = Cytogeneticist
# Company Name = Smith-Wong
# Location of Job = Lake Destiny, AP
#
# Title of Job = Designer, multimedia
# Company Name = Pierce-Herrera
# Location of Job = South Timothyburgh, AP
#
# Title of Job = Trade union research officer
# Company Name = Aguilar, Rivera and Quinn
# Location of Job = New Jimmyton, AE
#
# Title of Job = Chemist, analytical
# Company Name = Lowe, Barnes and Thomas
# Location of Job = New Lucasbury, AP
#
# Title of Job = Programmer, multimedia
# Company Name = Lewis, Gonzalez and Vasquez
# Location of Job = Port Cory, AE
#
# Title of Job = Engineer, broadcasting (operations)
# Company Name = Taylor PLC
# Location of Job = Gileston, AA
#
# Title of Job = Teacher, primary school
# Company Name = Oliver, Jones and Ramirez
# Location of Job = Cindyshire, AA
#
# Title of Job = Python Developer
# Company Name = Rivera and Sons
# Location of Job = East Michaelfort, AA
#
# Title of Job = Manufacturing systems engineer
# Company Name = Garcia PLC
# Location of Job = Joybury, AE
#
# Title of Job = Producer, television/film/video
# Company Name = Johnson, Wells and Kramer
# Location of Job = Emmatown, AE
#
# Title of Job = Scientist, forensic
# Company Name = Gonzalez LLC
# Location of Job = Colehaven, AP
#
# Title of Job = Bonds trader
# Company Name = Morgan, White and Macdonald
# Location of Job = Port Coryton, AE
#
# Title of Job = Editorial assistant
# Company Name = Robinson-Fitzpatrick
# Location of Job = Amyborough, AA
#
# Title of Job = Photographer
# Company Name = Waters, Wilson and Hoover
# Location of Job = Reynoldsville, AA
#
# Title of Job = Retail banker
# Company Name = Hill LLC
# Location of Job = Port Billy, AP
#
# Title of Job = Jewellery designer
# Company Name = Li-Gregory
# Location of Job = Adamburgh, AA
#
# Title of Job = Ophthalmologist
# Company Name = Fisher, Ryan and Coleman
# Location of Job = Wilsonmouth, AA
#
# Title of Job = Back-End Web Developer (Python, Django)
# Company Name = Stewart-Alexander
# Location of Job = South Kimberly, AA
#
# Title of Job = Licensed conveyancer
# Company Name = Abbott and Sons
# Location of Job = Benjaminland, AP
#
# Title of Job = Futures trader
# Company Name = Bryant, Santana and Davenport
# Location of Job = Zacharyport, AA
#
# Title of Job = Counselling psychologist
# Company Name = Smith PLC
# Location of Job = Port Devonville, AE
#
# Title of Job = Insurance underwriter
# Company Name = Patterson-Singh
# Location of Job = East Thomas, AE
#
# Title of Job = Engineer, automotive
# Company Name = Martinez-Berry
# Location of Job = New Jeffrey, AP
#
# Title of Job = Producer, radio
# Company Name = May, Taylor and Fisher
# Location of Job = Davidside, AA
#
# Title of Job = Dispensing optician
# Company Name = Bailey, Owen and Thompson
# Location of Job = Jamesville, AA
#
# Title of Job = Designer, fashion/clothing
# Company Name = Vasquez Ltd
# Location of Job = New Kelly, AP
#
# Title of Job = Chartered loss adjuster
# Company Name = Leblanc LLC
# Location of Job = Lake Antonio, AA
#
# Title of Job = Back-End Web Developer (Python, Django)
# Company Name = Jackson, Ali and Mckee
# Location of Job = New Elizabethside, AA
#
# Title of Job = Forest/woodland manager
# Company Name = Blankenship, Knight and Powell
# Location of Job = Millsbury, AE
#
# Title of Job = Clinical cytogeneticist
# Company Name = Patton, Haynes and Jones
# Location of Job = Lloydton, AP
#
# Title of Job = Print production planner
# Company Name = Wood Inc
# Location of Job = Port Jeremy, AA
#
# Title of Job = Systems developer
# Company Name = Collins Group
# Location of Job = New Elizabethtown, AA
#
# Title of Job = Graphic designer
# Company Name = Flores-Nelson
# Location of Job = Charlesstad, AE
#
# Title of Job = Writer
# Company Name = Mitchell, Jones and Olson
# Location of Job = Josephbury, AE
#
# Title of Job = Field seismologist
# Company Name = Howard Group
# Location of Job = Seanfurt, AA
#
# Title of Job = Chief Strategy Officer
# Company Name = Kramer-Edwards
# Location of Job = Williambury, AA
#
# Title of Job = Air cabin crew
# Company Name = Berry-Houston
# Location of Job = South Jorgeside, AP
#
# Title of Job = Python Programmer (Entry-Level)
# Company Name = Mathews Inc
# Location of Job = Robertborough, AP
#
# Title of Job = Warden/ranger
# Company Name = Riley-Johnson
# Location of Job = South Saratown, AP
#
# Title of Job = Sports therapist
# Company Name = Spencer and Sons
# Location of Job = Hullview, AA
#
# Title of Job = Arts development officer
# Company Name = Camacho-Sanchez
# Location of Job = Philipland, AP
#
# Title of Job = Printmaker
# Company Name = Oliver and Sons
# Location of Job = North Patty, AE
#
# Title of Job = Health and safety adviser
# Company Name = Eaton PLC
# Location of Job = North Stephen, AE
#
# Title of Job = Manufacturing systems engineer
# Company Name = Stanley-Frederick
# Location of Job = Stevensland, AP
#
# Title of Job = Programmer, applications
# Company Name = Bradley LLC
# Location of Job = Reyesstad, AE
#
# Title of Job = Medical physicist
# Company Name = Parker, Goodwin and Zavala
# Location of Job = Bellberg, AP
#
# Title of Job = Media planner
# Company Name = Kim-Miles
# Location of Job = North Johnland, AE
#
# Title of Job = Software Developer (Python)
# Company Name = Moreno-Rodriguez
# Location of Job = Martinezburgh, AE
#
# Title of Job = Surveyor, land/geomatics
# Company Name = Brown-Ortiz
# Location of Job = Joshuatown, AE
#
# Title of Job = Legal executive
# Company Name = Hartman PLC
# Location of Job = West Ericstad, AA
#
# Title of Job = Librarian, academic
# Company Name = Brooks Inc
# Location of Job = Tuckertown, AE
#
# Title of Job = Barrister
# Company Name = Washington-Castillo
# Location of Job = Perezton, AE
#
# Title of Job = Museum/gallery exhibitions officer
# Company Name = Nguyen, Yoder and Petty
# Location of Job = Lake Abigail, AE
#
# Title of Job = Radiographer, diagnostic
# Company Name = Holder LLC
# Location of Job = Jacobshire, AP
#
# Title of Job = Database administrator
# Company Name = Yates-Ferguson
# Location of Job = Port Susan, AE
#
# Title of Job = Furniture designer
# Company Name = Ortega-Lawrence
# Location of Job = North Tiffany, AA
#
# Title of Job = Ship broker
# Company Name = Fuentes, Walls and Castro
# Location of Job = Michelleville, AP
